# %% [markdown]
# # More Important Functions

# %%
import numpy as np
import pandas as pd

# %%
# value_counts (series and DF)
a = pd.Series([1,1,1,2,2,3])
a.value_counts()
# Out:
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
marks = pd.DataFrame({'marks': [10, 20, 30, 40, 50, 60, 70, 80, 90, 90],
                    'grade': ['D', 'C', 'C', 'B', 'B', 'A', 'A', 'A', 'A', 'A'],
                    'iq': [80, 85, 90, 95, 100, 105, 110, 115, 120, 120]})
marks.value_counts()
# Out:
# marks  grade  iq
# 90     A      120    2
# 10     D      80     1
# 20     C      85     1
# 30     C      90     1
# 40     B      95     1
# 50     B      100    1
# 60     A      105    1
# 70     A      110    1
# 80     A      115    1
# Name: count, dtype: int64

# %%
ipl = pd.read_csv("/Users/harsh/VS Code Codes/Juypter Data Science/Datasets/datasets-session-17/ipl-matches.csv")

# %%
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision SuperOver     WinningTeam    WonBy  Margin method  \
# 0          bat         N  Gujarat Titans  Wickets     7.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon

# %%
knockouts = ipl[~ipl['MatchNumber'].str.isdigit()]

# %%
knockouts['Player_of_Match']
# Out:
# 0              HH Pandya
# 1             JC Buttler
# 2             RM Patidar
# 3              DA Miller
# 74          F du Plessis
# 75               VR Iyer
# 76             SP Narine
# 77            RD Gaikwad
# 134             TA Boult
# 135           MP Stoinis
# 136        KS Williamson
# 137            JJ Bumrah
# 194            JJ Bumrah
# 195         F du Plessis
# 196              RR Pant
# 197             SA Yadav
# 254            SR Watson
# 255          Rashid Khan
# 256           AD Russell
# 257         F du Plessis
# 314            KH Pandya
# 315            KV Sharma
# 316      NM Coulter-Nile
# 317    Washington Sundar
# 373          BCJ Cutting
# 374            DA Warner
# 375         MC Henriques
# 376       AB de Villiers
# 433            RG Sharma
# 434              A Nehra
# 435       AB de Villiers
# 436           KA Pollard
# 492            MK Pandey
# 493             V Sehwag
# 494             SK Raina
# 495             UT Yadav
# 552           KA Pollard
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
b = ipl['Team1'].value_counts()

# %%
a = ipl['Team2'].value_counts()

# %%
(a + b).sort_values(ascending = False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
movies = pd.read_csv("/Users/harsh/VS Code Codes/Juypter Data Science/Datasets/datasets-session-17/movies.csv")

# %%
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
movies.sort_values('title_x', ascending = False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
temp = pd.DataFrame({'data': [1,2,3,np.nan,5,6,np.nan,8,np.nan,10]})

# %%
temp
# Out:
#    data
# 0   1.0
# 1   2.0
# 2   3.0
# 3   NaN
# 4   5.0
# 5   6.0
# 6   NaN
# 7   8.0
# 8   NaN
# 9  10.0

# %%
temp.sort_values('data', ascending=False)
# Out:
#    data
# 9  10.0
# 7   8.0
# 5   6.0
# 4   5.0
# 2   3.0
# 1   2.0
# 0   1.0
# 3   NaN
# 6   NaN
# 8   NaN

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
movies.sort_values(['title_x'])
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release'])
# Out:
#                                 title_x     imdb_id  \
# 1577                 Aashiq (2001 film)   tt0273406
# 1593                   Farz (2001 film)   tt0272607
# 1592                Ehsaas: The Feeling   tt0302524
# 1591  Dil Ne Phir Yaad Kiya (2001 film)   tt0273535
# 1590                        Deewaanapan   tt0301179
# ...                                 ...         ...
# 56                          Prassthanam   tt8706884
# 57               P Se Pyaar F Se Faraar  tt10816510
# 58                    Ghost (2019 film)   tt9378950
# 60                   Yaaram (2019 film)  tt11007050
# 0              Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1593  https://upload.wikimedia.org/wikipedia/en/thum...
# 1592                                                NaN
# 1591  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release', 'title_x'], ascending=[False, True])
# Out:
#                                    title_x     imdb_id  \
# 21                                22 Yards   tt9496212
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 10                                  Amavas   tt8396186
# 46                           Arjun Patiala   tt7881524
# 37                       Article 15 (film)  tt10324144
# ...                                    ...         ...
# 1573                   Yaadein (2001 film)   tt0248617
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1623                              Zubeidaa   tt0255713
#
#                                             poster_path  \
# 21    https://upload.wikimedia.org/wikipedia/en/thum...
# 26    https://upload.wikimedia.org/wikipedia/en/thum...
# 10    https://upload.wikimedia.org/wikipedia/en/thum...
# 46    https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
batsman = pd.read_csv("/Users/harsh/VS Code Codes/Juypter Data Science/Datasets/datasets-session-17/batsman_runs_ipl.csv")

# %%
batsman.sample(5)
# Out:
#                batter  batsman_run
# 157           DR Sams           44
# 344  Mashrafe Mortaza            2
# 155  DPMD Jayawardene         1808
# 562            U Kaul            0
# 536     Sohail Tanvir           36

# %%
batsman['batsman_rank'] = batsman['batsman_run'].rank(ascending=False)

# %%
batsman.sort_values('batsman_rank')
# Out:
#            batter  batsman_run  batsman_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]

# %%
batsman
# Out:
#              batter  batsman_run  batsman_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman.reset_index
# Out:
# <bound method DataFrame.reset_index of              batter  batsman_run  batsman_rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]>

# %%
batsman.set_index('batsman_rank')
# Out:
#                       batter  batsman_run
# batsman_rank
# 166.5         A Ashish Reddy          280
# 226.0               A Badoni          161
# 535.0             A Chandila            4
# 329.0               A Chopra           53
# 402.5            A Choudhary           25
# ...                      ...          ...
# 594.0             Yash Dayal            0
# 343.0          Yashpal Singh           47
# 547.5            Younis Khan            3
# 27.0            Yuvraj Singh         2754
# 256.0                 Z Khan          117
#
# [605 rows x 2 columns]

# %%
movies.rename(columns={'title_x': 'title'}, inplace=True)

# %%
movies.head(1)
# Out:
#                             imdb_id  \
# title_x
# Uri: The Surgical Strike  tt8291224
#
#                                                                 poster_path  \
# title_x
# Uri: The Surgical Strike  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                   wiki_link  \
# title_x
# Uri: The Surgical Strike  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                                            title_y            original_title  \
# title_x
# Uri: The Surgical Strike  Uri: The Surgical Strike  Uri: The Surgical Strike
#
#                           is_adult  year_of_release runtime            genres  \
# title_x
# Uri: The Surgical Strike         0             2019     138  Action|Drama|War
#
#                           imdb_rating  imdb_votes  \
# title_x
# Uri: The Surgical Strike          8.4       35112
#
#                                                                       story  \
# title_x
# ...

# %%
ipl['Season'].unique() # counts np.nan also
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
ipl['Season'].unique().shape[0] # don't count np.nan
# Out:
# 15

# %%
ipl['Season'].nunique()
# Out:
# 15

# %%
students = {
    'name': ['Harsh', 'Rohan', 'Karan', None],
    'marks': [10, 20, 30, np.nan],
    'grade': ['D', 'C', 'B', None]
}

df = pd.DataFrame(students)

# %%
df
# Out:
#     name  marks grade
# 0  Harsh   10.0     D
# 1  Rohan   20.0     C
# 2  Karan   30.0     B
# 3   None    NaN  None

# %%
df.isnull()
# Out:
#     name  marks  grade
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3   True   True   True

# %%
df.notnull()
# Out:
#     name  marks  grade
# 0   True   True   True
# 1   True   True   True
# 2   True   True   True
# 3  False  False  False

# %%
df.fillna(0)
# Out:
#     name  marks grade
# 0  Harsh   10.0     D
# 1  Rohan   20.0     C
# 2  Karan   30.0     B
# 3      0    0.0     0

# %%
df.dropna()
# Out:
#     name  marks grade
# 0  Harsh   10.0     D
# 1  Rohan   20.0     C
# 2  Karan   30.0     B

# %%
df.drop(columns=['grade'])
# Out:
#     name  marks
# 0  Harsh   10.0
# 1  Rohan   20.0
# 2  Karan   30.0
# 3   None    NaN

# %%
df.drop(index = [3])
# Out:
#     name  marks grade
# 0  Harsh   10.0     D
# 1  Rohan   20.0     C
# 2  Karan   30.0     B

# %%
df.set_index('name').drop(index = ['Rohan'])
# Out:
#        marks grade
# name
# Harsh   10.0     D
# Karan   30.0     B
# None     NaN  None
