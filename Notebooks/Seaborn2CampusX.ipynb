# %%
import seaborn as sns
import pandas as pd

# %%
iris = pd.read_csv('/Users/harsh/VS Code Codes/Juypter Data Science/Datasets/datasets-session-24/iris.csv')

# %%
tips = pd.read_csv('/Users/harsh/VS Code Codes/Juypter Data Science/Datasets/datasets-session-23/tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.stripplot(x='day', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind = 'strip')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind = 'strip', jitter = 1.5, hue = 'sex')

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind = 'strip', jitter = 1.5)

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind = 'swarm', hue = 'sex')
